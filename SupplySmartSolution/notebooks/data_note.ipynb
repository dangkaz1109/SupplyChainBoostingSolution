# %%
import duckdb 

conn = duckdb.connect()
conn_mem = duckdb.connect(database=':memory:')


conn_data = duckdb.connect("SupplyChain.db")

# %%
print(conn_data.get_table_names)
# Out:
# <bound method pybind11_detail_function_record_v1_msvc_md_mscver19.get_table_names of <_duckdb.DuckDBPyConnection object at 0x00000204F8A7F670>>
